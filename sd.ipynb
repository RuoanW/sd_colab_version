# %% [markdown]
# # Use instructions:
# 1. Decide which models, textual inversions, LoRA's, ControlNets, and VAE you wan to load, then uncomment them in the corresponding sections (remove the '#' in front of the line)
#
# 2. Click run (▸) and wait
#
#   It usually takes a minimum of 5-10 minutes to start the webui
#
#   Time to start the webui depends on how many files need to be downloaded

# %%
# Clone stable-diffusion-webui and sd-webui-tunnels from github

# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# !git clone https://github.com/Bing-su/sd-webui-tunnels /content/stable-diffusion-webui/extensions/sd-webui-tunnels

#######################################################################################################################################

# Uncomment the next line to use the images browser extension
#!git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# Uncomment the next line to use the tagcomplete extension
#!git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete /content/stable-diffusion-webui/extensions/a1111-sd-webui-tagcomplete

#######################################################################################################################################

# Model
# Download time is approx. 1-2 min per model
# Uncomment the models you need to use, or add other models using this syntax below:
# !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/xxx.safetensors download_link

# v1.5 ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned.ckpt https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned.ckpt

# v1.5-emaonly ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.ckpt https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt

# chilloutmix ↓
# !curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/chilloutmixni.safetensors https://civitai.com/api/download/models/11745

# deliberate
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/deliberate.safetensors https://civitai.com/api/download/models/15236

# grapefruit ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/grapefruit.safetensors https://civitai.com/api/download/models/16619

# protogen (photorealism) ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/protogen_photorealism.safetensors https://civitai.com/api/download/models/4048

# protogen (anime) ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/protogen_anime.safetensors https://civitai.com/api/download/models/4007

# dream shaper ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/dream_shaper.safetensors https://civitai.com/api/download/models/5636

# perfect world ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/perfect_world.safetensors https://civitai.com/api/download/models/19084

# abyss orange mix 3 (AOM3) ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/abyss_orange_mix3.safetensors https://civitai.com/api/download/models/17233

# counterfeit v2.5 ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/counterfeit.safetensors https://civitai.com/api/download/models/7425

# pastel mix ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/pastelmix.safetensors https://civitai.com/api/download/models/6297

# realdosmix ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/realdosmix.safetensors https://civitai.com/api/download/models/8137

# dalcefo_painting ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/dalcefo_painting.safetensors https://civitai.com/api/download/models/18446

# meinamix ↓
#!curl -Lo /content/stable-diffusion-webui/models/Stable-diffusion/meinamix.safetensors https://civitai.com/api/download/models/20322

# Add your own!
#!curl -Lo ...

#######################################################################################################################################

# Textual inversion
# Download time is negligible
# Uncomment the textual inversions you need to use, or add other textual inversions using this syntax below:
# !curl -Lo /content/stable-diffusion-webui/embeddings/xxx.pt download_link

# pure eros face ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/pure_eros_face.pt https://civitai.com/api/download/models/5119

# ulzzang-6500 ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/ulzzang-6500.pt https://civitai.com/api/download/models/10107

# bad-hands-5 ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/bad-hands-5.pt https://huggingface.co/yesyeahvh/bad-hands-5/resolve/main/bad-hands-5.pt

# bad_prompt ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/bad_prompt.pt https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt.pt

# bad_prompt_version2 ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/bad_prompt_version2.pt https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt_version2.pt

# charturnerv2 ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/charturnerv2.pt https://civitai.com/api/download/models/9857

# ng_deepnegative_v1_75t ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/ng_deepnegative_v1_75t.pt https://civitai.com/api/download/models/5637

# verybadimagenegative_v1.2-6400 ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/verybadimagenegative_v1.2-6400.pt https://civitai.com/api/download/models/15556

# bad-image-v2-39000 ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/bad-image-v2-39000.pt https://huggingface.co/Xynon/models/resolve/main/experimentals/TI/bad-image-v2-39000.pt

# easynegative ↓
#!curl -Lo /content/stable-diffusion-webui/embeddings/easynegative.pt https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.pt

# Add your own!
#!curl -Lo ...

#######################################################################################################################################

# LoRA (OPTIONAL)
# Download takes moderate amount of time

# IF YOU WANT TO USE LORA, UNCOMMENT THE LINE BELOW ↓
#!git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks

# Then, uncomment the LoRA you want to download, or add other LoRA using the following syntax:
# !curk -Lo /content/stable-diffusion-webui/models/Lora/xxx.safetensors download_link

# Japanese-doll-likeness ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Japanese-doll-likeness.safetensors https://huggingface.co/AnonPerson/ChilloutMix/resolve/main/Japanese-doll-likeness.safetensors

# Taiwan-doll-likeness ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Taiwan-doll-likeness.safetensors https://huggingface.co/AnonPerson/ChilloutMix/resolve/main/Taiwan-doll-likeness.safetensors

# Korean-doll-likeness ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/Korean-doll-likeness.safetensors https://huggingface.co/AnonPerson/ChilloutMix/resolve/main/Korean-doll-likeness.safetensors

# St. Louis (Luxurious Wheels) (Azur Lane) ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/st_louis.safetensors https://civitai.com/api/download/models/7840

# fashion_girl ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/fashion_girl.safetensors https://civitai.com/api/download/models/20073

# tifa_meenow ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/tifa_meenow.safetensors https://civitai.com/api/download/models/16793

# GENSHIN IMPACT SECTION

# yaeMikoRealistic_yaemikoMixed ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/yaeMikoRealistic_yaemikoMixed.safetensors https://civitai.com/api/download/models/11523

# raiden_shogun ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/raiden_shogun.safetensors https://civitai.com/api/download/models/19827

# shenhe ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/shenhe.safetensors https://civitai.com/api/download/models/5545

# ganyu ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/ganyu.safetensors https://civitai.com/api/download/models/13958

# amber ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/amber.safetensors https://civitai.com/api/download/models/5105

# yelan ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/yelan.safetensors https://civitai.com/api/download/models/5548

# nilou ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/nilou.safetensors https://civitai.com/api/download/models/6238

# hutao ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/hutao.safetensors https://civitai.com/api/download/models/14479

# lisa ↓
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/lisa.safetensors https://civitai.com/api/download/models/5331

# Add your own!
#!curl -Lo ...

#######################################################################################################################################

# ControlNet (OPTIONAL)

# IF YOU WANT TO USE CONTROLNET EXTENSION, UNCOMMENT THE LINE BELOW:
#!git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet

# Then select the ControlNet you want to download, or add other ControlNets using the syntax below:
# !curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/xxx.safetensors download_link

# canny
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_canny.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_canny.pth

# depth
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_depth.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_depth.pth

# hed
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_hed.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_hed.pth

# mlsd
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_mlsd.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_mlsd.pth

# normal
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_normal.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_normal.pth

# openpose
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_openpose.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_openpose.pth

# scribble
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_scribble.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_scribble.pth

# seg
#!curl -Lo /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_sd15_seg.safetensors https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_seg.pth

# Add your own!
#!curl -Lo

#######################################################################################################################################

# VAE (OPTIONAL)
# Uncomment if you wish to use this VAE, or download other VAE to the same directory
#!curl -Lo /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.ckpt https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt

# Or use your own!
#!curl ...

#######################################################################################################################################

# %cd /content/stable-diffusion-webui
# Launch
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --xformers --reinstall-xformers --enable-insecure-extension- --gradio-queue --remotemoe" REQS_FILE="requirements.txt" python launch.py
# Installing dependencies takes a few minutes

# %%
# If additional models or LoRA's are required, stop executing the previous block, and add additional models or LoRA's below using the same syntax
# The last line will relaunch stable-diffusion webui
# You can do this as many times as you like

# !curl -Lo /content/stable-diffusion-webui/...... download_link

# Launch
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --xformers --reinstall-xformers --enable-insecure-extension- --gradio-queue --remotemoe" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# # References:
#
# stable-diffusion-webui created by [AUTOMATIC1111](https://github.com/AUTOMATIC1111)
#
# sd-webui-tunnels created by [Bing-su](https://github.com/Bing-su)
#
# stable-diffusion-webui-images-browser created by [yfszzx](https://github.com/yfszzx)
#
# Models, textual inversions, and LoRA's retrieved from [huggingface](https://huggingface.co) and [civitai](https://civitai.com)
#
# ControlNet and VAE retrieved from [huggingface](https://huggingface.co)
